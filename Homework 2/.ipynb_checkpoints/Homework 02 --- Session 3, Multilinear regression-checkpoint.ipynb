# %% [markdown]
# # Homework 02 --- Session 3, Multilinear regression

# %%
from __future__ import print_function, division
import pylab as pl
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
import requests
# %pylab inline

import os


#plus importing scipy.stats
import scipy.stats
from mpl_toolkits.mplot3d import Axes3D 
from sklearn.model_selection import train_test_split
from collections import OrderedDict

pl.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## EX 1 Artificial data (25pt -- 5+5+5+10)
# ### Dataset 'H31.csv'

# %% [markdown]
# ### Tasks:
# Consider a multivariate regression of the output variable $y$ over the 3 regressors $x_1$, $x_2$, $x_3$ as follows.
# * (a) Which one of the regressors serves as dummy variable corresponding to an intercept term?
#     * Ignore the first column since it's just a duplicate index (You can avoid it by running **ex1 = pd.read_csv('H31.csv', index_col=0)** )

# %%
ex1 = pd.read_csv('data/H31.csv', index_col=0)
ex1
# Out:
#    y  x1  x2  x3
# 1  0   1  -2   1
# 2  2  -1  -1   1
# 3  2   0   0   1
# 4  3  -1   1   1
# 5  3   1   2   1

# %% [markdown]
# **Answer：**
# Since the dummy variable usually represents a mutex, a value of 0 causes the coefficient of the variable to have no effect on the dependent variable, and when the dummy value is 1, its coefficient is used to change the intercept. Therefore, from the table, x3 is serves as dummy variable.

# %% [markdown]
# * (b) Calculate the coefficients $\hat w$ manually or with python *numpy* module by using matrix computation.

# %%
X = np.matrix(ex1[['x3','x1','x2']])
Y = np.matrix(ex1.y).T
w = (X.T * X).I * X.T * Y
print(w)
# Out:
# [[ 2. ]
#  [-0.5]
#  [ 0.7]]

# %% [markdown]
# * (c) Verify your answer by implementing the OLS regression function with python *statsmodels* module.

# %%
lm1_ex1 = smf.ols(formula = 'y~x1+x2',data=ex1).fit()
print(lm1_ex1.params)
# Out:
# Intercept    2.0
# x1          -0.5
# x2           0.7
# dtype: float64

# %%
w1 = []
[w1.append(x[0]) for x in w.tolist()]
pd.DataFrame({'Matrix_Computation':w1,'OLS Regression':lm1_ex1.params})
# Out:
#            Matrix_Computation  OLS Regression
# Intercept                 2.0             2.0
# x1                       -0.5            -0.5
# x2                        0.7             0.7

# %% [markdown]
# the coefficients $\hat w$ is identical.

# %% [markdown]
# * (d) Visualize the data points and your fitted model in a 3D plot, like we did in the lab session.

# %%
fig = pl.figure(figsize=(8,8))
ax = fig.gca(projection='3d')
ax.scatter(ex1.x1,ex1.x2,ex1.y,s=100,c='r')

radius = 5
x1,x2 = np.meshgrid(range(-radius,radius), range(-radius,radius))
fit_y = lm1_ex1.params[0] + lm1_ex1.params[1]*x1 + lm1_ex1.params[2]*x2

ax.plot_surface(x1,x2,fit_y,color='c',alpha=0.4)

ax.set_xlabel('$x_1$', fontsize = 20)
ax.set_ylabel('$x_2$', fontsize = 20)
ax.set_zlabel('$y$', fontsize = 20)

ax.view_init(azim = 60)

# %% [markdown]
# ## EX 2, Income vs Insurance coverage (35+10pt -- 10+10+5+10+10)
# ### Dataset 'IncomeInsReg.csv'

# %% [markdown]
# You are given the demographic data of insurance coverage in NYC, with the details:
# * Zip code
# * Per capita income
# * Total population (for each zip code)
# * Population with Insurance coverage
#     * Population with Public Insurance coverage
#     * Population with Private Insurance coverage
# * Population with No Insurance coverage
#
# ### Tasks:
# * (a) Verify that there are some people with BOTH public insurance and private insurance according to this data set, then create a new column containing such information

# %%
ex2 = pd.read_csv('data/IncomeInsReg.csv')
ex2.head(2)
# Out:
#    Zipcode  IncomePerCapita  TotalPop  WithCoverage  Public  Private  \
# 0    10001          77512.0     22767         20809    5800    16795
# 1    10002          26905.0     79490         70361   40139    35167
#
#    NoCoverage
# 0        1958
# 1        9129

# %%
ex2a= pd.DataFrame(np.array(ex2.Public + ex2.Private + ex2.NoCoverage - ex2.TotalPop),columns=['BothPublicAndPrivate'])
ex2a.head()
# Out:
#    BothPublicAndPrivate
# 0                  1786
# 1                  4945
# 2                  3980
# 3                   105
# 4                    70

# %% [markdown]
# * (b) Modify the old data frame, or simply create a new one, such that this data frame contains (including but not limited to) the following information in each zipcode area:
#     * IncomePerCapita
#     * Total Population
#     * Population with Public Insurance coverage ONLY
#     * Population with Private Insurance coverage ONLY
#     * Population with NO Insurance coverage
#     * Population with BOTH types of Insurance coverage

# %%
ex2['PublicOnly'] = ex2.Public - ex2a.BothPublicAndPrivate
ex2['PrivateOnly'] = ex2.Private - ex2a.BothPublicAndPrivate
ex2['BothPublicAndPrivate'] = ex2a
ex2.head()
# Out:
#    Zipcode  IncomePerCapita  TotalPop  WithCoverage  Public  Private  \
# 0    10001          77512.0     22767         20809    5800    16795
# 1    10002          26905.0     79490         70361   40139    35167
# 2    10003          79088.0     56909         53135    8593    48522
# 3    10004          98020.0      3024          2780     180     2705
# 4    10005          99633.0      7566          6996     122     6944
#
#    NoCoverage  PublicOnly  PrivateOnly  BothPublicAndPrivate
# 0        1958        4014        15009                  1786
# 1        9129       35194        30222                  4945
# 2        3774        4613        44542                  3980
# 3         244          75         2600                   105
# 4         570          52         6874                    70

# %%
ex2.drop(['WithCoverage','Public','Private'], axis=1,inplace=True)
ex2.head()
# Out:
#    Zipcode  IncomePerCapita  TotalPop  NoCoverage  PublicOnly  PrivateOnly  \
# 0    10001          77512.0     22767        1958        4014        15009
# 1    10002          26905.0     79490        9129       35194        30222
# 2    10003          79088.0     56909        3774        4613        44542
# 3    10004          98020.0      3024         244          75         2600
# 4    10005          99633.0      7566         570          52         6874
#
#    BothPublicAndPrivate
# 0                  1786
# 1                  4945
# 2                  3980
# 3                   105
# 4                    70

# %% [markdown]
# * (c) Drop rows with NaN (if any) and convert all population counts into proportions (percentage of total population, with the form 58.3 instead of 0.583)

# %%
ex2 = ex2.dropna(axis=0)

# %%
for i in range(3,len(ex2.columns)):
    ex2.iloc[:,i] = ex2.iloc[:,i] / ex2.TotalPop * 100

# %%
ex2.head()
# Out:
#    Zipcode  IncomePerCapita  TotalPop  NoCoverage  PublicOnly  PrivateOnly  \
# 0    10001          77512.0     22767    8.600167   17.630781    65.924364
# 1    10002          26905.0     79490   11.484463   44.274752    38.019877
# 2    10003          79088.0     56909    6.631640    8.105923    78.268815
# 3    10004          98020.0      3024    8.068783    2.480159    85.978836
# 4    10005          99633.0      7566    7.533703    0.687285    90.853820
#
#    BothPublicAndPrivate
# 0              7.844687
# 1              6.220908
# 2              6.993621
# 3              3.472222
# 4              0.925192

# %% [markdown]
# * (d) Regress over these proportions (the ones mentioned in part b, leave out "No Insurance Coverage") to predict income -- What interesting results do we have here? Briefly state what you've obtained.

# %% [markdown]
# #### Extra credit:
# * (e) Visualize the observed income versus the predicted income, like what we did in the lab session. Does this fitted line look great or not? If you're not sure, check the correlation matrix and make a guess.

# %%
ex2['TotalIncome'] = ex2.IncomePerCapita * ex2.TotalPop

# %%
train, valid = train_test_split(ex2, test_size = 0.3)

# %%
lm1_ex2 = smf.ols(formula = 'TotalIncome~TotalPop+PrivateOnly+PublicOnly+BothPublicAndPrivate',data=train).fit()

# %%
def modelEval(lm, key = 'TotalIncome'):
    lmy = lm.predict(valid)
    y_err = lmy - valid[key]
    y_norm = valid[key]-mean(valid[key])
    R2 = 1-y_err.dot(y_err)/y_norm.dot(y_norm)  # R2 w.r.t. validation set
    print('Validation R^2 is %f'%R2)
    print(lm.summary())
    plt.plot(lmy, lmy, 'b-')
    plt.plot(lmy, valid[key],'or')

# %%
modelEval(lm1_ex2)
# Out:
# Validation R^2 is 0.479667
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TotalIncome   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     41.78
# Date:                Sun, 22 Oct 2017   Prob (F-statistic):           5.77e-22
# Time:                        21:36:21   Log-Likelihood:                -2761.9
# No. Observations:                 126   AIC:                             5534.
# Df Residuals:                     121   BIC:                             5548.
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -4.706e+09   1.51e+09     -3.123      0.002   -7.69e+09   -1.72e+09
# TotalPop              3.275e+04   3079.617     10.634      0.000    2.67e+04    3.88e+04
# PrivateOnly           6.984e+07   1.63e+07      4.281      0.000    3.75e+07    1.02e+08
# PublicOnly            2.684e+07   1.97e+07      1.363      0.175   -1.21e+07    6.58e+07
# BothPublicAndPrivate  4.988e+07   1.76e+07      2.833      0.005     1.5e+07    8.47e+07
# ==============================================================================
# Omnibus:                       46.118   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.593
# Skew:                           1.576   Prob(JB):                     2.88e-21
# Kurtosis:                       5.844   Cond. No.                     1.10e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Since the p-value of PublicOnly is much higher than others,I would try to remove it.**

# %%
lm2_ex2 = smf.ols(formula = 'TotalIncome~TotalPop+PrivateOnly+BothPublicAndPrivate',data=ex2).fit()

# %%
modelEval(lm2_ex2)
# Out:
# Validation R^2 is 0.558739
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TotalIncome   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     76.72
# Date:                Sun, 22 Oct 2017   Prob (F-statistic):           7.71e-32
# Time:                        21:38:22   Log-Likelihood:                -3960.0
# No. Observations:                 181   AIC:                             7928.
# Df Residuals:                     177   BIC:                             7941.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -2.666e+09   2.97e+08     -8.964      0.000   -3.25e+09   -2.08e+09
# TotalPop              3.339e+04   2469.033     13.525      0.000    2.85e+04    3.83e+04
# PrivateOnly           4.467e+07   3.67e+06     12.165      0.000    3.74e+07    5.19e+07
# BothPublicAndPrivate  3.872e+07   1.11e+07      3.482      0.001    1.68e+07    6.07e+07
# ==============================================================================
# Omnibus:                       78.676   Durbin-Watson:                   1.298
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              235.697
# Skew:                           1.834   Prob(JB):                     6.59e-52
# Kurtosis:                       7.219   Cond. No.                     2.74e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Now p-value is tiny enough(p < 5% ) that we can take a conclusion:
#
# The impact of the Total Population, Private Only and both Private&Public insurance population are statistically significant (p-value < 5%) on income.
#
# In addition, the validation R2 is improved so the fit is good

# %% [markdown]
# ## EX 3, Polynomial fit (40+30pt -- 4+5+3$\times$4+5+3$\times$3+5+30)
#
# ### Try to fit y with a polynomial $$\hat y(x,w) = \sum\limits_{i=1}^M w_i\cdot x^i$$ with the given dataset 'H33.csv'

# %%
ex3 = pd.read_csv('data/H33.csv')
ex3.head()
# Out:
#           y    x1
# 0  2.613388 -0.50
# 1  2.170351 -0.32
# 2  0.049546 -0.14
# 3  1.158258  0.04
# 4  1.397567  0.22

# %% [markdown]
# ### Tasks:
# * (a) Draw the scatter plot of x and y, guess what polynomial could be the best choice. (The name "x1" denotes $x^1$.)

# %%
pl.figure(figsize=[8,8])
pl.scatter(ex3.x1,ex3.y,label='y')
pl.xlabel('x')
pl.ylabel('y')
pl.legend()
pl.show()

# %% [markdown]
# guess the Quadratic could be the best choice.

# %% [markdown]
# * (b) Create new columns in data frame to contain the information of $x^2, x^3, x^4$

# %%
for i in range(2,5):
    ex3['x'+str(i)] = ex3.x1 ** i

# %%
ex3
# Out:
#           y    x1      x2        x3        x4
# 0  2.613388 -0.50  0.2500 -0.125000  0.062500
# 1  2.170351 -0.32  0.1024 -0.032768  0.010486
# 2  0.049546 -0.14  0.0196 -0.002744  0.000384
# 3  1.158258  0.04  0.0016  0.000064  0.000003
# 4  1.397567  0.22  0.0484  0.010648  0.002343
# 5  1.773240  0.40  0.1600  0.064000  0.025600

# %% [markdown]
# * (c) Try to fit y with polynomial of x with order 1, 2, 3, 4, respectively
#     * For each model, store your fitted parameters as well as your $R^2$

# %%
n = len(ex3.columns)-1

# %%
def MultiReg(data, degree):
    # First create a string for controlling the number of x_i
    string = ''
    for i in range(degree):
        string += str(i+1)  # For example, if degree == 3, then this string would be '123' at the end
    formula = 'y ~ x' + ' + x'.join(string) # join function will convert '123' to '1 + x2 + x3'

    # Perform regression and return the results
    lm = smf.ols(formula = formula, data = data).fit()
    return lm.rsquared, lm.params


# Run the function and store the results separately
R2 = []; Params = []
for M in range(1,5):
    a,b = MultiReg(ex3,M)  # For each M, run the function
    R2.append(a)
    Params.append(b)
R2
# Out:
# [0.10479617162381583,
#  0.65125881311682743,
#  0.66574886312199211,
#  0.80198630229302026]

# %% [markdown]
# * (d) Report the $R^2$, plot it and observe how it changes

# %%
pl.figure(figsize=[10,5])
pl.plot(range(1,n+1),regR2,'r-*',markersize=10,label='$R^2$')
pl.legend()
pl.show()

# %% [markdown]
# * (e) Create a figure with four (4) subfigures, one for each polynomial degree M = 1, 2, 3, 4. In each subfigure:
#     * (e.1) Draw the original scatter plot of x1 and y
#     * (e.2) Plot the curve of true function $f(x) = 9x^2 - x + 1$
#     * (e.3) Plot your fitted curve of degree M, observe how our model fits the data as M increases

# %%
ex3
# Out:
#           y    x1      x2        x3        x4
# 0  2.613388 -0.50  0.2500 -0.125000  0.062500
# 1  2.170351 -0.32  0.1024 -0.032768  0.010486
# 2  0.049546 -0.14  0.0196 -0.002744  0.000384
# 3  1.158258  0.04  0.0016  0.000064  0.000003
# 4  1.397567  0.22  0.0484  0.010648  0.002343
# 5  1.773240  0.40  0.1600  0.064000  0.025600

# %%
fig = pl.figure(figsize=[12,12])
g = lambda x: (9*(x**2) - x +1)
for M in [1,2,3,4]:
    ax = fig.add_subplot(2,2,M)
    ax.scatter(ex3.x1,ex3.y,label='original x1 & y',c='r')
    polyfit = np.polyfit(ex3.x1, ex3.y, M)
    f = np.poly1d(polyfit)
    x_new = np.linspace(ex3.x1.min(), ex3.x1.max(), 10000)
    y_new = f(x_new)
    lmy = f(ex3.x1)
    y_err = lmy - ex3.y
    y_norm = ex3.y - np.mean(ex3.y)
    R2 = 1-y_err.dot(y_err)/y_norm.dot(y_norm)
    ax.plot(x_new,g(x_new),label='true function',c='b')
    ax.plot(x_new,y_new,label='polynomial fit',c='g')    
    ax.legend()
    formula = 'y = '+ str(round(f.coeffs[-1],4)) 
    for i in range(len(f),0,-1):
        formula = formula + ' + '+ str(round(f.coeffs[len(f)-i],4)) + '$x^'+str(i)+'$'
    ax.set_title('M = {}\n $R^2$ = {} \n {}'.format(M,R2,formula))
fig.suptitle('Fitting for y and x1', y = 0.92,fontsize=16)

# %% [markdown]
# * (f) Based on the plot, which model(s) fits the true curve best? Then provide the best coefficients $\hat w$

# %% [markdown]
# from the plot, polynomial model with degree of freedom 2 fits the true curve best.

# %%
polyfit = np.polyfit(ex3.x1, ex3.y, 2)
f = np.poly1d(polyfit)
print(f)
# Out:
#        2
# 7.459 x - 0.1129 x + 0.7979

# %% [markdown]
# ### Extra credit
# * (g) In each subfigure:
#     * (g.1) Pick an x value (at your discretion) $x_0$, then locate the y value both on your fitted curve and on our function curve ($f(x_0)$)
#
#     * (g.2) Mark these two points with a small diamond, then draw a dashed line connecting them, showing "prediction error"

# %%
fig = pl.figure(figsize=[16,16])
g = lambda x: (9*(x**2) - x +1)
for M in [1,2,3,4]:
    ax = fig.add_subplot(2,2,M)
    ax.scatter(ex3.x1,ex3.y,label='original x1 & y',c='r')
    polyfit = np.polyfit(ex3.x1, ex3.y, M)
    f = np.poly1d(polyfit)
    np.random.seed(999)
    x0 = np.random.uniform(np.min(ex3.x1),np.max(ex3.x1))
    x_new = np.linspace(ex3.x1.min(), ex3.x1.max(), 10000)
    y_new = f(x_new)
    lmy = f(ex3.x1)
    y_err = lmy - ex3.y
    y_norm = ex3.y - np.mean(ex3.y)
    R2 = 1-y_err.dot(y_err)/y_norm.dot(y_norm)
    ax.plot(x0,g(x0),'yd',markersize=12,label='x picked on true function')
    ax.plot(x0,f(x0),'kd',markersize=12,label='x picked on fitted function')
    ax.plot([x0,x0],[g(x0),f(x0)],'--',label='prediction error')
    prediction_error = g(x0)-f(x0)
    ax.plot(x_new,g(x_new),label='true function',c='b')
    ax.plot(x_new,y_new,label='polynomial fit',c='g')    
    ax.legend()
    formula = 'y = '+ str(round(f.coeffs[-1],4)) 
    for i in range(len(f),0,-1):
        formula = formula + ' + '+ str(round(f.coeffs[len(f)-i],4)) + '$x^'+str(i)+'$'
    ax.set_title('M = {}\n $R^2$ = {} \n {}\n Prediction Error = {}'.format(M,R2,formula,prediction_error))
fig.suptitle('Fitting for y and x1', y = 0.92,fontsize=16)

# %% [markdown]
# * (g.3) Repeat g.1 and g.2 up to ten times (i.e. select up to ten random different future points and predict their values, compare your prediction with the true value), then:
#     * Compute the average sum of squares of errors $E = \frac{\sum_i^n (y_i - f(x_i))^2}{n}$ ($x_i$ denotes your future points), mention it in your subfigure's title (**Be sure to use the SAME future points for ALL 4 models when you calculate prediction error**)
#     * Which model has the smallest average error $E$? Does this fitted polynomial coincides with the M you picked in part f?

# %%
fig = pl.figure(figsize=[20,20])
g = lambda x: (9*(x**2) - x +1)
for M in [1,2,3,4]:
    ax = fig.add_subplot(2,2,M)
    ax.scatter(ex3.x1,ex3.y,label='original x1 & y',c='r')
    polyfit = np.polyfit(ex3.x1, ex3.y, M)
    f = np.poly1d(polyfit)
    np.random.seed(999)
    prediction_error = []
    yi = []
    xi = []
    fxi = []
    for i in range(10):
        x0 = np.random.uniform(np.min(ex3.x1),np.max(ex3.x1))
        ax.plot(x0,g(x0),'yd',markersize=12,label='x picked on true function')
        ax.plot(x0,f(x0),'kd',markersize=12,label='x picked on fitted function')
        ax.plot([x0,x0],[g(x0),f(x0)],'--',label='prediction error')
        prediction_error.append(-g(x0)+f(x0))
        xi.append(x0)
        yi.append(g(x0))
        fxi.append(f(x0))
    x_new = np.linspace(ex3.x1.min(), ex3.x1.max(), 10000)
    y_new = f(x_new)
    lmy = f(ex3.x1)
    y_err = lmy - ex3.y
    y_norm = ex3.y - np.mean(ex3.y)
    R2 = 1-y_err.dot(y_err)/y_norm.dot(y_norm)
    prediction_error = np.mean(prediction_error)
    E = np.sum((np.array(fxi) - np.array(yi))**2)/10
    ax.plot(x_new,g(x_new),label='true function',c='b')
    ax.plot(x_new,y_new,label='polynomial fit',c='g')    
    # Make label only one
    handles, labels = pl.gca().get_legend_handles_labels()
    by_label = OrderedDict(zip(labels, handles))
    pl.legend(by_label.values(), by_label.keys())
    formula = 'y = '+ str(round(f.coeffs[-1],4)) 
    
    for i in range(len(f),0,-1):
        formula = formula + ' + '+ str(round(f.coeffs[len(f)-i],4)) + '$x^'+str(i)+'$'
    ax.set_title('M = {}\n $R^2$ = {} \n {}\n Mean Prediction Error = {}\n E = {}'.format(M,R2,formula,prediction_error,E))
fig.suptitle('Fitting for y and x1', y = 0.92,fontsize=16)

# %% [markdown]
# **Model with M = 2 has the smallest average error E = 0.179.And this did fit polynomial coincides with the M I picked in part f**
